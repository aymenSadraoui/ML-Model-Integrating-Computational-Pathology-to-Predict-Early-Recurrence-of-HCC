# %% [markdown]
# ### This operation is to resize the patches for inflammatory cells detection to reduce the computation time

# %%
import os
from PIL import Image
from tqdm import tqdm

if not os.path.exists("../data/patches_bis"):
    os.mkdir("../data/patches_bis")

# %%
for patches in os.listdir("../data/patches"):
    print(patches)
    for patch_dir in tqdm(os.listdir("../data/patches/" + patches)):
        if not os.path.exists("../data/patches_bis/" + patches):
            os.mkdir("../data/patches_bis/" + patches)
        img = Image.open("../data/patches/" + patches + "/" + patch_dir)
        if not os.path.exists("../data/patches_bis/" + patches + "/" + patch_dir):
            if img.size == (1152, 1152):
                img.resize((512, 512)).save(
                    "../data/patches_bis/" + patches + "/" + patch_dir
                )
            elif img.size == (626, 626):
                img.resize((278, 278)).save(
                    "../data/patches_bis/" + patches + "/" + patch_dir
                )
            else:
                img.resize((486, 486)).save(
                    "../data/patches_bis/" + patches + "/" + patch_dir
                )
# Out:
# 167D
# 100%|██████████| 4588/4588 [02:30<00:00, 30.54it/s]
# 222B
# 100%|██████████| 4665/4665 [00:02<00:00, 2096.54it/s]
# 120C
# 100%|██████████| 3715/3715 [00:00<00:00, 5305.18it/s]
# 111C
# 100%|██████████| 5025/5025 [00:00<00:00, 6852.79it/s]
# 121C
# 100%|██████████| 4993/4993 [00:00<00:00, 5865.14it/s]
# 111A
# 100%|██████████| 5860/5860 [00:01<00:00, 5744.95it/s]
# 120B
# 100%|██████████| 4177/4177 [00:00<00:00, 6741.48it/s]
# 111B
# 100%|██████████| 4096/4096 [00:00<00:00, 6226.65it/s]
# 36I
# 100%|██████████| 1942/1942 [00:00<00:00, 3087.15it/s]
# 36H
# 100%|██████████| 3459/3459 [00:00<00:00, 4178.23it/s]
# 120A
# 100%|██████████| 4585/4585 [00:00<00:00, 6201.02it/s]
# 164D
# 100%|██████████| 3833/3833 [02:03<00:00, 30.96it/s]
# 121B
# 100%|██████████| 5036/5036 [00:00<00:00, 6422.07it/s]
# 164B
# 100%|██████████| 5838/5838 [00:00<00:00, 6055.61it/s]
# 222C
# 100%|██████████| 5012/5012 [00:00<00:00, 5892.51it/s]
# 222A
# 100%|██████████| 5444/5444 [00:02<00:00, 2096.74it/s]
# 164C
# 100%|██████████| 7120/7120 [03:35<00:00, 33.06it/s]
# 121D
# 100%|██████████| 3275/3275 [00:00<00:00, 5387.28it/s]
# 121A
# 100%|██████████| 4382/4382 [00:00<00:00, 6104.04it/s]
# 167C
# 100%|██████████| 6202/6202 [03:09<00:00, 32.68it/s]
# 164A
# 100%|██████████| 5991/5991 [03:10<00:00, 31.47it/s]
