# %% [markdown]
# ### This operation is to resize the patches for inflammatory cells detection to reduce the computation time

# %%
import os
from PIL import Image
from tqdm import tqdm

if not os.path.exists("../data/patches_bis"):
    os.mkdir("../data/patches_bis")

# %%
for patches in os.listdir("../data/patches"):
    print(patches)
    for patch_dir in tqdm(os.listdir("../data/patches/" + patches)):
        if not os.path.exists("../data/patches_bis/" + patches):
            os.mkdir("../data/patches_bis/" + patches)
        img = Image.open("../data/patches/" + patches + "/" + patch_dir)
        if not os.path.exists("../data/patches_bis/" + patches + "/" + patch_dir):
            if img.size == (1152, 1152):
                img.resize((512, 512)).save(
                    "../data/patches_bis/" + patches + "/" + patch_dir
                )
            elif img.size == (626, 626):
                img.save("../data/patches_bis/" + patches + "/" + patch_dir)
            else:
                img.resize((512, 512)).save(
                    "../data/patches_bis/" + patches + "/" + patch_dir
                )
# Out:
# 167D
# 100%|██████████| 4588/4588 [02:29<00:00, 30.65it/s]
# 222B
# 100%|██████████| 4665/4665 [02:37<00:00, 29.71it/s]
# 120C
# 100%|██████████| 3715/3715 [00:13<00:00, 266.23it/s]
# 111C
# 100%|██████████| 5025/5025 [00:24<00:00, 206.28it/s]
# 121C
# 100%|██████████| 4993/4993 [00:18<00:00, 272.66it/s]
# 111A
# 100%|██████████| 5860/5860 [00:25<00:00, 230.39it/s]
# 120B
# 100%|██████████| 4177/4177 [00:38<00:00, 108.12it/s]
# 111B
# 100%|██████████| 4096/4096 [00:16<00:00, 253.01it/s]
# 36I
# 100%|██████████| 1942/1942 [01:13<00:00, 26.52it/s]
# 36H
# 100%|██████████| 3459/3459 [02:06<00:00, 27.29it/s]
# 120A
# 100%|██████████| 4585/4585 [00:48<00:00, 94.34it/s]
# 164D
# 100%|██████████| 3833/3833 [02:06<00:00, 30.20it/s]
# 121B
# 100%|██████████| 5036/5036 [00:20<00:00, 248.71it/s]
# 164B
# 100%|██████████| 5838/5838 [03:21<00:00, 28.91it/s]
# 222C
# 100%|██████████| 5012/5012 [02:56<00:00, 28.34it/s]
# 222A
# 100%|██████████| 5444/5444 [03:04<00:00, 29.46it/s]
# 164C
# 100%|██████████| 7120/7120 [04:18<00:00, 27.59it/s]
# 121D
# 100%|██████████| 3275/3275 [00:12<00:00, 267.25it/s]
# 121A
# 100%|██████████| 4382/4382 [00:15<00:00, 280.62it/s]
# 167C
# 100%|██████████| 6202/6202 [03:38<00:00, 28.33it/s]
# 164A
# 100%|██████████| 5991/5991 [03:16<00:00, 30.49it/s]
